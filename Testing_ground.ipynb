# %%
import feedparser
from time import mktime
from datetime import datetime
from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch  # type: ignore
import pandas as pd
import re

# %%
# Choose the feed type
news_type = "crude_oil"  # Options: "crude_oil", "gas_lng"

# RSS URLs per news type
RSS_FEEDS = {
    "crude_oil": [
        "https://news.google.com/rss/search?q=Bloomberg+oil+news",
        "https://news.google.com/rss/search?q=Reuters+oil+news",
        "https://news.google.com/rss/search?q=Oilprice.com+crude+news",
    ],
    "gas_lng": [
        "https://news.google.com/rss/search?q=Bloomberg+gas+news",
        "https://news.google.com/rss/search?q=Reuters+gas+news",
        "https://news.google.com/rss/search?q=Reuters+LNG+news",
        "https://news.google.com/rss/search?q=Bloomberg+LNG+news",
        "https://news.google.com/rss/search?q=Oilprice.com+LNG+gas+news",
    ],
}

rss_urls = RSS_FEEDS.get(news_type, RSS_FEEDS["crude_oil"])

# %%
def fetch_and_sort_feeds(urls):
    all_entries = []
    seen_titles = set()
    
    for url in urls:
        try:
            feed = feedparser.parse(url)
            for entry in feed.entries:
                if entry.title not in seen_titles:
                    seen_titles.add(entry.title)
                    if hasattr(entry, 'published_parsed'):
                        entry.published_dt = datetime.fromtimestamp(mktime(entry.published_parsed))
                    else:
                        entry.published_dt = None
                    all_entries.append(entry)
        except Exception as e:
            print(f"Error fetching {url}: {e}")
    
    sorted_entries = sorted(
        all_entries,
        key=lambda e: e.published_dt or datetime.min,
        reverse=True
    )
    
    return sorted_entries

# Fetch entries
entries = fetch_and_sort_feeds(rss_urls)

# %%
def display_entries(entries, limit=20):
    for entry in entries[:limit]:
        print(f"\n📰 {entry.title}")
        print(f"📅 {entry.published_dt.strftime('%Y-%m-%d %H:%M:%S') if entry.published_dt else 'No date'}")
        print(f"🔗 {entry.link}")
        if hasattr(entry, 'summary'):
            print(entry.summary[:300] + '...')
        print("-" * 80)

display_entries(entries)
# Out:
# 📰 Oil Edges Higher as Trump Extends Tariff Deadline on EU Goods - Bloomberg.com
# 📅 2025-05-26 02:00:00
# 🔗 https://news.google.com/rss/articles/CBMingFBVV95cUxOZlVQei1DaTFKSmFVdE1fMkNtMHBPS1RGczMydkZyVjh6THVxdGExTjJtTGtWN0NQZ24zbE1NdEdoVWNLR1Z1SWFYNGp4TDNLdVY5UXRHcmtyVkVOOC1lbThDczhzQkk1R29BTjFJZXF5X2ZOaGl6TFJQY01USXVjcGpZS0VyeHB4Yll0Mndoc2lSSnpFYVZVSDlrM0dRdw?oc=5
# <a href="https://news.google.com/rss/articles/CBMingFBVV95cUxOZlVQei1DaTFKSmFVdE1fMkNtMHBPS1RGczMydkZyVjh6THVxdGExTjJtTGtWN0NQZ24zbE1NdEdoVWNLR1Z1SWFYNGp4TDNLdVY5UXRHcmtyVkVOOC1lbThDczhzQkk1R29BTjFJZXF5X2ZOaGl6TFJQY01USXVjcGpZS0VyeHB4Yll0Mndoc2lSSnpFYVZVSDlrM0dRdw?oc=5" target="_blank">Oil Edges Hig...
# --------------------------------------------------------------------------------
#
# 📰 PHP/USD: Philippine Peso Gains to Strongest Since 2023 on Dollar, Oil - Bloomberg.com
# 📅 2025-05-26 01:06:00
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" target=...
# --------------------------------------------------------------------------------
#
# 📰 Oil climbs after Trump extends EU trade talks deadline to July - Reuters
# 📅 2025-05-26 00:07:14
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" targe...
# --------------------------------------------------------------------------------
#
# 📰 OPEC Takes Aim at U.S. Shale, Again - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-25 23:00:00
# 🔗 https://news.google.?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 USGS Discovers Large Oil & Gas Deposits In Wyoming - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-25 21:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Trump's Foreign Policy Shifts Reshape European Defense Strategy - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-25 15:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Canada's Atlantic LNG Dreams Just Got Pricier - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-24 23:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Real Estate Sector Under Pressure to Decarbonize - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-24 17:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 US Plans Chevron License for Minimum Upkeep in Venezuela - Bloomberg.com
# 📅 2025-05-24 15:36:47
# 🔗 https://news.google.?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 New Trade Routes Drive India's Eurasian Ambitions - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-24 15:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 EU Weighs Cutting 20 Banks From SWIFT in New Russia Sanctions - Bloomberg.com
# 📅 2025-05-24 07:03:53
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" tar...
# --------------------------------------------------------------------------------
#
# 📰 Lithium Iron Phosphate Batteries Drive Market Boom - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-23 23:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Rare Earths Supply Chain Strains Persist Despite Trade Truce - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-23 21:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Hedge Funds Turn More Bullish on Brent Oil as Iran Talks Stall - Bloomberg.com
# 📅 2025-05-23 20:23:09
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" t...
# --------------------------------------------------------------------------------
#
# 📰 Oil Set for Weekly Drop as OPEC+ Weighs Another Big Supply Hike - Bloomberg.com
# 📅 2025-05-23 19:24:01
# 🔗 https://news.google.com/rss/articles/CBMingFBVV95cUxOekRSLXVYcHFtc1ZKcjQ4YXdSai0tYTJ2VDg5ZlNYd1lCWlNqejFqdmpfaG0tdGplR0k0TkczSG5PR05hSnZrSFFIRkxXeFB0TV9SaUdOMkdJLXR1eVpLX3ZmME1XWm9HUnZJSENmamJJS09yMGVXMjJjNUdHZE01UTZBbC1SdDNOMDh1d1B4Szd0cjdNcTFWRDB5VDZUQQ?oc=5
# <a href="https://news.google.com/rss/articles/CBMingFBVV95cUxOekRSLXVYcHFtc1ZKcjQ4YXdSai0tYTJ2VDg5ZlNYd1lCWlNqejFqdmpfaG0tdGplR0k0TkczSG5PR05hSnZrSFFIRkxXeFB0TV9SaUdOMkdJLXR1eVpLX3ZmME1XWm9HUnZJSENmamJJS09yMGVXMjJjNUdHZE01UTZBbC1SdDNOMDh1d1B4Szd0cjdNcTFWRDB5VDZUQQ?oc=5" target="_blank">Oil Set for W...
# --------------------------------------------------------------------------------
#
# 📰 Oil gains on short-covering, nuclear talks - Reuters
# 📅 2025-05-23 19:21:33
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" targe...
# --------------------------------------------------------------------------------
#
# 📰 Carney’s Energy Chief Pushes Oil Sands to Build Carbon-Capture Systems - Bloomberg.com
# 📅 2025-05-23 19:00:29
# 🔗 https://news.google.?oc=5
# <a href="https://news.google.?oc=5" t...
# --------------------------------------------------------------------------------
#
# 📰 G7 Finance Ministers Consider Stepped-Up Sanctions Against Russia - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-23 19:00:00
# 🔗 https://news.google.-AUFVX3lxTE1RTVBqZEY2a2djdG54SjJJWGVDZGUyRHdIZ3QzZFJ0UlNxRWFPZGtvQ1JqaVExRVNJR2Zvd1VwOWdGX0wyWDc0QjZHVHpDQ3NiNnFTNVlMMGE5TmF2YTlUUkRka0hZdFpQcEhkLUdGbEN5Si11QW1zZ1RaYXNmOFloWXJ0Y19yU05ZVnVDNjl1MWNJSFZFRUw5X21RX1F6WmVPczBLOHQ0Q3BGanB4SGFxUW9UWVR4bGRrMHlSa1E?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 $53 Billion Guyana Oil Clash Heads to London Tribunal - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-23 18:00:00
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------
#
# 📰 Oil Rig Count Plunges Amid Scary Price Environment - Crude Oil Prices Today | OilPrice.com
# 📅 2025-05-23 17:09:51
# 🔗 https://news.google....?oc=5
# <a href="https://news.google....
# --------------------------------------------------------------------------------

# %%
# Initialize Google Gemini Client
client = genai.Client(api_key="AIzaSyA0jZkj5buSGm6AXtXlo6CEeFS1f8q0KSg")  # Use Streamlit secrets for safety
model_id = "gemini-2.0-flash"
google_search_tool = Tool(google_search=GoogleSearch())

def get_sentiment_for_title(entry, model, model_id):
    prompt = (
        f"What is the sentiment to the crude oil market for this news title:\n"
        f"'{entry.title}'\n\n"
        "Return a one-word sentiment (Bullish, Bearish, Neutral, or Unrelated) "
        "and a two-sentence explanation."
    )
    
    try:
        response = model.models.generate_content(
            model=model_id,
            contents=prompt,
            config=GenerateContentConfig(
                tools=[google_search_tool],
                response_modalities=["TEXT"],
            )
        )
        full_text = "\n".join([part.text for part in response.candidates[0].content.parts]).strip()

        # Attempt to extract the one-word sentiment and explanation
        sentiment_match = re.search(r"\b(Bullish|Bearish|Neutral|Unrelated)\b", full_text, re.IGNORECASE)
        sentiment = sentiment_match.group(0).capitalize() if sentiment_match else "Unknown"

        explanation = re.sub(r"(?i)\b(Bullish|Bearish|Neutral|Unrelated)\b[:\-]?\s*", "", full_text, count=1).strip()

        return {
            "Title": entry.title,
            "Date": entry.published_dt.strftime("%Y-%m-%d") if entry.published_dt else "N/A",
            "Sentiment": sentiment,
            "Reasoning": explanation
        }

    except Exception as e:
        return {
            "Title": entry.title,
            "Date": entry.published_dt.strftime("%Y-%m-%d") if entry.published_dt else "N/A",
            "Sentiment": "Error",
            "Reasoning": str(e)
              }

# %%
# Limit to top 5 news items
sentiment_data = [get_sentiment_for_title(entry, client, model_id) for entry in entries[:20]]

# Convert to DataFrame
df = pd.DataFrame(sentiment_data)

# Show the table
df
# Out:
#                                                 Title        Date Sentiment  \
# 0   Oil Edges Higher as Trump Extends Tariff Deadl...  2025-05-26   Bullish
# 1   PHP/USD: Philippine Peso Gains to Strongest Si...  2025-05-26   Neutral
# 2   Oil climbs after Trump extends EU trade talks ...  2025-05-26   Bullish
# 3   OPEC Takes Aim at U.S. Shale, Again - Crude Oi...  2025-05-25   Bearish
# 4   USGS Discovers Large Oil & Gas Deposits In Wyo...  2025-05-25   Bearish
# 5   Trump's Foreign Policy Shifts Reshape European...  2025-05-25   Bearish
# 6   Canada's Atlantic LNG Dreams Just Got Pricier ...  2025-05-24   Bearish
# 7   Real Estate Sector Under Pressure to Decarboni...  2025-05-24   Bearish
# 8   US Plans Chevron License for Minimum Upkeep in...  2025-05-24   Neutral
# 9   New Trade Routes Drive India's Eurasian Ambiti...  2025-05-24   Bullish
# 10  EU Weighs Cutting 20 Banks From SWIFT in New R...  2025-05-24   Bearish
# 11  Lithium Iron Phosphate Batteries Drive Market ...  2025-05-23   Bearish
# 12  Rare Earths Supply Chain Strains Persist Despi...  2025-05-23   Bearish
# 13  Hedge Funds Turn More Bullish on Brent Oil as ...  2025-05-23   Bullish
# 14  Oil Set for Weekly Drop as OPEC+ Weighs Anothe...  2025-05-23   Bearish
# 15  Oil gains on short-covering, nuclear talks - R...  2025-05-23   Bullish
# 16  Carney’s Energy Chief Pushes Oil Sands to Buil...  2025-05-23   Bearish
# 17  G7 Finance Ministers Consider Stepped-Up Sanct...  2025-05-23   Bullish
# 18  $53 Billion Guyana Oil Clash Heads to London T...  2025-05-23   Bearish
# 19  Oil Rig Count Plunges Amid Scary Price Environ...  2025-05-23   Bearish
#
#                                             Reasoning
# 0   ****\n\nThe extension of the tariff deadline s...
# 1   Based on the news title and the context of the...
# 2   **Sentiment:** **Explanation:** The extension ...
# 3   ****\n\nOPEC taking aim at U.S. shale suggests...
# 4   **Sentiment:** **Explanation:** The discovery ...
# 5   **Sentiment:** **Explanation:** The news title...
# 6   ****\n\nThe news title suggests rising costs f...
# 7   ****\n\nThe real estate sector's push to decar...
# 8   . The news suggests the US is allowing Chevron...
# 9   ****\n\nThe news suggests India is expanding i...
# 10  ****\n\nThe news suggests increased sanctions ...
# 11  **Sentiment:** **Explanation:** The news title...
# 12  Based on the news title, the sentiment towards...
# 13  **Sentiment:** **Explanation:** The title indi...
# 14  ****\n\nThe news suggests a potential increase...
# 15  Short-covering suggests that investors who pre...
# 16  **.**\n\nThe news suggests increased costs for...
# 17  **Sentiment:** **Explanation:** Stepped-up san...
# 18  **Sentiment:** **Explanation:** A $53 billion ...
# 19  **Sentiment:** **Explanation:** A plunge in th...

# %%
import re

def clean_sentiment_response(entry, model, model_id):
    prompt = (
        f"What is the sentiment to the crude oil market for this news title:\n"
        f"'{entry.title}'\n\n"
        "Return a one-word sentiment (Bullish, Bearish, Neutral, or Unrelated) "
        "and a two-sentence explanation."
    )
    
    try:
        response = model.models.generate_content(
            model=model_id,
            contents=prompt,
            config=GenerateContentConfig(
                tools=[google_search_tool],
                response_modalities=["TEXT"],
            )
        )
        full_text = "\n".join([part.text for part in response.candidates[0].content.parts]).strip()

        # Extract the sentiment
        sentiment_match = re.search(r"\b(Bullish|Bearish|Neutral|Unrelated)\b", full_text, re.IGNORECASE)
        sentiment = sentiment_match.group(0).capitalize() if sentiment_match else "Unknown"

        # Remove known prefixes like "Sentiment:" or "Explanation:" and clean
        cleaned = re.sub(r"\*\*.*?\*\*", "", full_text)  # Remove bold markdown
        cleaned = re.sub(r"(Sentiment|Explanation)\s*[:\-]*", "", cleaned, flags=re.IGNORECASE)
        cleaned = cleaned.replace("\n", " ").strip()

        # Try to remove the sentiment word if it's at the start
        cleaned = re.sub(rf"^{sentiment}\b[:\-]*\s*", "", cleaned, flags=re.IGNORECASE)

        return {
            "Title": entry.title,
            "Date": entry.published_dt.strftime("%Y-%m-%d") if entry.published_dt else "N/A",
            "Sentiment": sentiment,
            "Reasoning": cleaned
        }

    except Exception as e:
        return {
            "Title": entry.title,
            "Date": entry.published_dt.strftime("%Y-%m-%d") if entry.published_dt else "N/A",
            "Sentiment": "Error",
            "Reasoning": str(e)
        }


# Run on your news entries (limit for speed)
cleaned_data = [clean_sentiment_response(entry, client, model_id) for entry in entries[:20]]

# Convert to DataFrame
df = pd.DataFrame(cleaned_data)

# View table
df
# Out:
#                                                 Title        Date Sentiment  \
# 0   Oil Edges Higher as Trump Extends Tariff Deadl...  2025-05-26   Bullish
# 1   PHP/USD: Philippine Peso Gains to Strongest Si...  2025-05-26   Bullish
# 2   Oil climbs after Trump extends EU trade talks ...  2025-05-26   Bullish
# 3   OPEC Takes Aim at U.S. Shale, Again - Crude Oi...  2025-05-25   Bearish
# 4   USGS Discovers Large Oil & Gas Deposits In Wyo...  2025-05-25   Bearish
# 5   Trump's Foreign Policy Shifts Reshape European...  2025-05-25   Bearish
# 6   Canada's Atlantic LNG Dreams Just Got Pricier ...  2025-05-24   Bearish
# 7   Real Estate Sector Under Pressure to Decarboni...  2025-05-24   Bearish
# 8   US Plans Chevron License for Minimum Upkeep in...  2025-05-24   Bearish
# 9   New Trade Routes Drive India's Eurasian Ambiti...  2025-05-24   Bullish
# 10  EU Weighs Cutting 20 Banks From SWIFT in New R...  2025-05-24   Bearish
# 11  Lithium Iron Phosphate Batteries Drive Market ...  2025-05-23   Bearish
# 12  Rare Earths Supply Chain Strains Persist Despi...  2025-05-23   Bearish
# 13  Hedge Funds Turn More Bullish on Brent Oil as ...  2025-05-23   Bullish
# 14  Oil Set for Weekly Drop as OPEC+ Weighs Anothe...  2025-05-23   Bearish
# 15  Oil gains on short-covering, nuclear talks - R...  2025-05-23   Neutral
# 16  Carney’s Energy Chief Pushes Oil Sands to Buil...  2025-05-23   Neutral
# 17  G7 Finance Ministers Consider Stepped-Up Sanct...  2025-05-23   Bullish
# 18  $53 Billion Guyana Oil Clash Heads to London T...  2025-05-23   Bearish
# 19  Oil Rig Count Plunges Amid Scary Price Environ...  2025-05-23   Bearish
#
#                                             Reasoning
# 0   The extension of the tariff deadline suggests ...
# 1   A stronger Philippine Peso against the US doll...
# 2   The extension of trade talks between the U.S. ...
# 3   The news title suggests that OPEC is actively ...
# 4   The discovery of large oil and gas deposits in...
# 5   The news title suggests that Trump's foreign p...
# 6   The news title suggests that Canada's LNG proj...
# 7   The news title suggests a downward pressure on...
# 8   The news suggests limited oil production from ...
# 9   The news suggests India is expanding its trade...
# 10  The news suggests increased sanctions against ...
# 11  The news suggests a growing market for lithium...
# 12  The news suggests that despite a trade truce, ...
# 13  Stalled Iran talks reduce the likelihood of in...
# 14  The title suggests a likely increase in oil su...
# 15  .  Short-covering suggests a temporary price i...
# 16  Based on the news title, the is .   The title ...
# 17  The news suggests potential supply disruptions...
# 18  A $53 billion legal clash suggests uncertainty...
# 19  The headline indicates a "plunge" in oil rig c...
